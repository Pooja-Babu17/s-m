# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
#lmplot

# %%
sns.lmplot(data=dataset, x="hsc_p", y="salary")

# %%
sns.lmplot(data=dataset, x="hsc_p", y="salary",hue="gender")
#hue, col, row string

# %%
sns.lmplot(
    data=dataset, x="hsc_p", y="salary",
    row="gender", height=4,
)

# %%
sns.lmplot(
    data=dataset, x="hsc_p", y="salary",
    col="gender",row="degree_t", height=4,
     facet_kws=dict(sharex=False, sharey=False)
)

# %%
(data, *, x=None, y=None, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=None, sharey=None, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, facet_kws=None)

# %%
#lmplot
lm = sns.lmplot(x="ssc_p", y="hsc_p", data=dataset, height=6)

# Set the title using Seaborn's FacetGrid
lm.fig.suptitle('Linear Regression Plot between SSC Percentage and HSC Percentage')
# Out:
# Text(0.5, 0.98, 'Linear Regression Plot between SSC Percentage and HSC Percentage')

# %%
#plot

# %%
(data, *, x=None, y=None, hue=None, col=None, row=None, palette=None, col_wrap=None, height=5, aspect=1, markers='o', sharex=None, sharey=None, hue_order=None, col_order=None, row_order=None, legend=True, legend_out=None, x_estimator=None, x_bins=None, x_ci='ci', scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None, seed=None, order=1, logistic=False, lowess=False, robust=False, logx=False, x_partial=None, y_partial=None, truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None, line_kws=None, facet_kws=None)

# %%
sns.scatterplot(x="ssc_p", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.scatterplot(x="ssc_p", y="hsc_p", hue="gender", size="ssc_b", data=dataset)
#multi
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
#just added title
scatter_plot = sns.scatterplot(x="ssc_p", y="hsc_p", hue="gender", size="ssc_b", data=dataset)

# Set the title using Seaborn's FacetGrid
scatter_plot.set(title='Scatter Plot between SSC Percentage and HSC Percentage')

# Show the plot
# Out:
# [Text(0.5, 1.0, 'Scatter Plot between SSC Percentage and HSC Percentage')]

# %% [markdown]
# #line plot

# %%
#sns.lineplot(x="", y="", data=)

# %%
sns.lineplot(x="ssc_p", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.displot(data=dataset, x="ssc_p", kde=True)

# %%
sns.displot(data=dataset, x="ssc_p", kde=True)

# %%
sns.set(style="ticks")

# Create a FacetGrid with 'gender' as the facet variable
g = sns.FacetGrid(dataset, col="gender", height=4)

# Map a histogram to the grid
g.map(sns.histplot, "ssc_p", kde=True)

# Set titles for each facet
g.set_titles("Histogram of SSC Percentage - {col_name}")

# %%
df_melted = pd.melt(dataset, id_vars='gender', value_vars=['ssc_p', 'hsc_p'], var_name='Education Level', value_name='Percentage')
sns.barplot(x="gender", y="Percentage", hue="Education Level", data=df_melted, palette="Set3", ci=None)
# Out:
# C:\Users\Pooja\AppData\Local\Temp\ipykernel_1056\3884832506.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="gender", y="Percentage", hue="Education Level", data=df_melted, palette="Set3", ci=None)
# <Axes: xlabel='gender', ylabel='Percentage'>

# %%
sns.catplot(y="Percentage", hue="Education Level", data=pd.melt(dataset, value_vars=['ssc_p', 'hsc_p'], var_name='Education Level', value_name='Percentage'), kind="bar", palette="Set3", ci=None, height=6, aspect=1.5).fig.suptitle('Grouped Categorical Plot of SSC and HSC Percentage', y=1.02)
# Out:
# C:\Users\Pooja\AppData\Local\Temp\ipykernel_1056\3569719468.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.catplot(y="Percentage", hue="Education Level", data=pd.melt(dataset, value_vars=['ssc_p', 'hsc_p'], var_name='Education Level', value_name='Percentage'), kind="bar", palette="Set3", ci=None, height=6, aspect=1.5).fig.suptitle('Grouped Categorical Plot of SSC and HSC Percentage', y=1.02)
# Text(0.5, 1.02, 'Grouped Categorical Plot of SSC and HSC Percentage')

# %%
df_melted = pd.melt(dataset, id_vars='gender', value_vars=['ssc_p', 'hsc_p'], var_name='Education Level', value_name='Percentage')
sns.boxplot(x="gender", y="Percentage", hue="Education Level", data=df_melted, palette="Set3")
# Out:
# <Axes: xlabel='gender', ylabel='Percentage'>

# %%
sns.violinplot(x="gender", y="hsc_p", data=dataset, hue="gender", palette="Set2", inner="quartile", legend=False)
# Out:
# <Axes: xlabel='gender', ylabel='hsc_p'>

# %%
df_melted = pd.melt(dataset, id_vars='gender', value_vars=['ssc_p', 'hsc_p'], var_name='Education Level', value_name='Percentage')
sns.violinplot(x="Education Level", y="Percentage", hue="gender", data=df_melted, palette="Set2", inner="quartile", split=True)
# Out:
# <Axes: xlabel='Education Level', ylabel='Percentage'>

# %%
sns.relplot(x="ssc_p", y="hsc_p", hue="gender", data=dataset, palette="Set2", height=6, aspect=1.5)

# %%
sns.jointplot(x="ssc_p", y="hsc_p", data=dataset, hue="gender")

# %%
sns.histplot(data=dataset, x="ssc_p")
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %%
sns.stripplot(x="gender", y="ssc_p", data=dataset, jitter=True, palette="Set2", size=8)
# Out:
# C:\Users\Pooja\AppData\Local\Temp\ipykernel_1056\890270581.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x="gender", y="ssc_p", data=dataset, jitter=True, palette="Set2", size=8)
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
g = sns.JointGrid(data=dataset, x="ssc_p", y="hsc_p")
g.plot(sns.scatterplot, sns.histplot)

# %%
g = sns.FacetGrid(dataset, col="gender", height=6, aspect=1.5)
g.map(sns.kdeplot, "ssc_p", fill=True)

# %%
# heatmap

# %%
#cluster map
#kde plot
#hist plot
#ecdfplot
#swarmplot
#regplot
#pair
#count
#styling

# %%
#color
seaborn.set_hls_values
seaborn.set_hls_values(h=None, l=None, s=None)
eg sns.set_hls_values(l=.5, s=.9)
h, l, and s are the hue, lightness, and saturation values, respectively.

***
seaborn.desaturate(color, prop)
prop 0 to 1
original_color = sns.color_palette("deep")[0]

# Desaturate the color by 30%
desaturated_color = sns.desaturate(original_color, prop=0.7)

****
seaborn.saturate(color)
# Original color in RGB tuple
original_color = sns.color_palette("deep")[0]

# Saturate the color
saturated_color = sns.saturate(original_color)

# %%
#LEGENT
seaborn.move_legend(obj, loc, **kwargs)
obj: The object with the plot. This argument can be either a Seaborn object (e.g., seaborn.FacetGrid or seaborn.PairGrid) or a Matplotlib object (matplotlib.axes.Axes or matplotlib.figure.Figure).

loc: Location argument, specified as a string or integer, similar to the loc parameter in matplotlib.axes.Axes.legend(). It determines where the legend will be placed in the plot. Common string values include 'upper right', 'upper left', 'lower right', 'lower left', 'right', 'center left', 'center right', 'lower center', 'upper center', and 'center'. Integer values can also be used to represent specific locations.


seaborn.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)kwargs: Other keyword arguments that are passed to matplotlib.axes.Axes.legend() for additional customization of the legend.

# %%
seaborn.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)


The seaborn.despine function in Seaborn is used to remove or adjust the appearance of the spines (the borders) of a plot. It provides a way to customize the visual style of the plot by controlling which spines are visible and their positions.


fig: A Matplotlib Figure instance. If provided, this specifies the figure on which to operate. If not provided, the current Figure is used.

ax: A Matplotlib Axes instance. If provided, this specifies the axes on which to operate. If not provided, the current Axes is used.

top, right, left, bottom: Boolean values indicating whether to remove the spines on the top, right, left, and bottom sides of the plot, respectively. If True, the spine is removed; if False, the spine is retained.

offset: A distance (in points) by which to offset the spines from the data area. This can be useful to make room for labels or other elements.

trim: If True, the spines are trimmed to the axis limits after offsetting. This can be useful when spines are offset to avoid overlapping with data points.

# %%
sns.lineplot(x="ssc_p", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.lmplot(data=dataset, x="hsc_p", y="salary")

# %%
sns.scatterplot(x="ssc_p", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='hsc_p'>

# %%
sns.displot(data=dataset, x="ssc_p", kde=True)

# %%
sns.barplot(x="gender", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='hsc_p'>

# %%
sns.catplot(x="hsc_p", y="hsc_p", data=dataset,kind="bar")

# %%
sns.boxplot(x="gender", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='hsc_p'>

# %%
sns.violinplot(x="gender", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='hsc_p'>

# %%
sns.relplot(x="ssc_p", y="hsc_p", hue="gender", data=dataset)

# %%
sns.stripplot(x="gender", y="ssc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sns.jointplot(x="ssc_p", y="hsc_p", data=dataset, hue="gender")

# %%
sns.jointplot(x="ssc_p", y="hsc_p", data=dataset)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    float64
#  1   ssc_p           215 non-null    float64
#  2   hsc_p           215 non-null    float64
#  3   degree_p        215 non-null    float64
#  4   etest_p         215 non-null    float64
#  5   mba_p           215 non-null    float64
#  6   salary          215 non-null    float64
#  7   gender          215 non-null    object
#  8   ssc_b           215 non-null    object
#  9   hsc_b           215 non-null    object
#  10  hsc_s           215 non-null    object
#  11  degree_t        215 non-null    object
#  12  workex          215 non-null    object
#  13  specialisation  215 non-null    object
#  14  status          215 non-null    object
# dtypes: float64(7), object(8)
# memory usage: 25.3+ KB

# %%
df=dataset.drop(columns=["gender","ssc_b","hsc_b","hsc_s","degree_t","workex","specialisation","status"],axis=1)
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0
#
# [215 rows x 7 columns]

# %%
sns.heatmap(df)
# Out:
# <Axes: >

# %%
df1=dataset.drop(columns=["gender","ssc_b","hsc_b","hsc_s","degree_t","workex","specialisation","status"],axis=1).head(6)
df1
# Out:
#    sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0    1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1    2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2    3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3    4.0  56.00  52.00     52.00     66.0  59.43       0.0
# 4    5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# 5    6.0  55.00  49.80     67.25     55.0  51.58       0.0

# %%
sns.heatmap(df1)
# Out:
# <Axes: >

# %%
sns.heatmap(df1,vmin=5,vmax=35,cmap="PuOr")
# Out:
# <Axes: >

# %%
sns.countplot(x="gender", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.pointplot(x="gender", y="hsc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='hsc_p'>

# %%
sns.pairplot(df1)

# %%
g = sns.FacetGrid(dataset, col="gender", height=6, aspect=1.5)
g.map(sns.kdeplot, "ssc_p", fill=True)

# %%
sns.FacetGrid(dataset,col="ssc_p",hue="gender")
g.map(sns.kdeplot)

# %%
sns.clustermap(df1)

# %%
sns.kdeplot(df1.ssc_p)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Density'>

# %%
sns.ecdfplot(x="ssc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Proportion'>

# %%
sns.swarmplot(x="gender", y="ssc_p", data=dataset)
# Out:
# <Axes: xlabel='gender', ylabel='ssc_p'>

# %%
sns.regplot(x="hsc_p", y="ssc_p", data=dataset)
# Out:
# <Axes: xlabel='hsc_p', ylabel='ssc_p'>

# %%
sns.histplot(x="ssc_p", data=dataset)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

# %%
#bar plot
plt.bar(df["hsc_p"], df["ssc_p"])
plt.xlabel("Higher Secondary Percentage (hsc_p)")
plt.ylabel("Secondary Percentage (ssc_p)")
plt.title("Comparison of Secondary and Higher Secondary Percentages")
plt.show()

# %%
plt.scatter(df["hsc_p"], df["ssc_p"])
plt.show()

# %%
plt.plot(df["hsc_p"], df["ssc_p"])
plt.show()

# %%
plt.stem(df["hsc_p"], df["ssc_p"])
plt.show()

# %%
plt.plot(df["hsc_p"], df["ssc_p"])
plt.show()

# %%
plt.step(df["hsc_p"], df["ssc_p"])
plt.show()

# %%
plt.hist(df["hsc_p"])
plt.show()

# %%
plt.boxplot(df["hsc_p"])
plt.show()

# %%
gender_counts = dataset.groupby("gender")["hsc_p"].sum()

plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)

plt.show()

# %%
plt.plot(df["hsc_p"], df["ssc_p"])
plt.fill_between(df["hsc_p"], df["ssc_p"], color='skyblue', alpha=0.4)
plt.show()

# %%
plt.imshow(df1)

# %%
column_name = "ssc_p"

column_data = dataset[column_name]

reshaped_data = np.expand_dims(column_data.values, axis=0)

plt.imshow(reshaped_data, cmap='viridis', aspect='auto')
plt.title(f'imshow for {column_name} column')
plt.xlabel('Index')
plt.ylabel(column_name)
plt.colorbar(label=column_name)
plt.show()

# %%
plt.contour(df1)

# %%
from matplotlib.animation import FuncAnimation

# Assuming df is your DataFrame
fig, ax = plt.subplots()
x_data = df["hsc_p"]
y_data = df["ssc_p"]
line, = ax.plot(x_data, y_data)

def update(frame):
    line.set_xdata(x_data[:frame])
    line.set_ydata(y_data[:frame])
    return line,

ani = FuncAnimation(fig, update, frames=len(x_data), interval=100, blit=True)
plt.xlabel("Higher Secondary Percentage (hsc_p)")
plt.ylabel("Secondary Percentage (ssc_p)")
plt.title("Animated Plot of Secondary and Higher Secondary Percentages")
plt.show()
